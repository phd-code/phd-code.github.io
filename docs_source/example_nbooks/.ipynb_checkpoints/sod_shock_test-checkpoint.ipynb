# %% [markdown]
# # Sod Shock Tube
# ### Context
# The Sod shock tube problem is a classic test of the code's ability to handle discontinuities (i.e. shocks) and trace their propagation. This is a simple example of a [Riemann problem](https://en.wikipedia.org/wiki/Riemann_problem), which is essentially just an initial-value problem for which we have a conservation equation subject to a piecewise discontinuous constant initial condition. In the case of the Sod shock tube, this amounts to having a fluid separated into two constant states, separated by some boundary/diaphragm across which the density and pressure are discontinuous. Formally, this can be written:
#
# $$ \rho(x)=   \left\{
# \begin{array}{ll}
#       \rho_L & x\leq x_\mathrm{crit} \\
#       \rho_R & x>x_\mathrm{crit} \\
# \end{array}
# \right.
# $$
#
# and
#
# $$ P(x)=   \left\{
# \begin{array}{ll}
#       P_L & x\leq x_\mathrm{crit} \\
#       P_R & x>x_\mathrm{crit} \\
# \end{array}
# \right.
# $$
#
# where the subscripts correspond to the 'left' and 'right' sides of the boundary at $x=x_\mathrm{crit}$. Generally, we will define $P_L$ and $P_R$ such that $P_R < P_L$. The following figure of the initial setup ($t=0$) for the 1D shock tube.
#
# ![Sod Setup](sod_setup.png)
#
# At $t=0$, the diaphragm is removed, and, because the fluid is initially at rest, this will initiate a flow from the higher pressure (left) to lower pressure (right) region. Conceptually, in an attempt to equalize te pressure, the fluid on the left will expand and flow into the right section, compressing the fluid there. This rarefaction occurs in a region known as the 'expansion fan' (2 in the diagram) that proceeds to the left, and, similarly, the compression proceeds to the right as a 'shock front' (the line separating 4 and 5 in the diagram). There is a 'boundary' between these two regions (the expanding and compressing fluids) across which the state variables of the fluid are discontinuous – this is the source of the difficulty for the code and is why this provides a good test. The following figure is a schematic visualization of what the aforementioned process looks like at $t>0$.
#
# ![Sod Final](solution_sod.png)
#
# Functionally, we need to solve the Euler equations to trace the evolution of the system over time and this corresponds to the aforementioned Riemann problem that we are solving. First, the Euler equations can be written in matrix form as follows (assuming no external body forces):
#
# $$
# \frac{\partial}{\partial t}\begin{pmatrix} \rho \\ \rho v \\ E \end{pmatrix} + \frac{\partial}{\partial x}\begin{pmatrix} \rho v\\ \rho v^2 + P \\ (E+P)v \end{pmatrix} = 0
# $$
#
# where the first equation is the continuity equation, the second is momentum conservation/the 'Euler' equation (flux of momentum density has an ordered component and pressure/random motion component), and the third is the energy conservation equation (energy flux similarly has a bulk transport component and pressure-driven component). In these equations, $\rho$ is the density, $P$ is the pressure, $E$ is the energy, and $v$ is the average velocity. In order to close the system, we need to specify an equation of state, so here we choose the polytropic EOS for an ideal gas, with $\gamma = 1.4$ (the ratio of specific heats is that of air).
#
# Using expressions derived from the characteristic form of the Euler equations (such as the Riemann invariants and the Rankine-Hugoniot shock jump conditions), we can relate the fluid quantities on either side of the shock, the expansion fan, and the contact discontinuity. With a lot of algebra, one can derive an implicit expression for the ratio of the *known* $p_1$ and $p_5$ pressures on either side of the diaphragm initially in terms of the ratio of *unknown* pressures $p_3$ and $p_4$ on either side of the contact. This can be solved iteratively, but this is often expensive, so we can use codes, such as this one, to approximate the solution more efficiently.

# %% [markdown]
# ### Using the code
# In any case, this is the perfect example of a situation where the code can be used to solve this Riemann problem. First, we can `import phd`.

# %%
import phd
import numpy as np

# %% [markdown]
# Now we need to set-up our particle grid. Here, we will be producing a two-dimensional grid of particles with the `HydroParticleCreator` method but for convenience, can package it all into a single method as below. This is useful if we were to, for example, initialize the code in parallel, rather than serial, as we can feed the `create_particles` method in as an argument to the `distribute_initial_particles` method. However, for our purposes, the serial implementation is sufficient, so `distribute_initial_particles` simply reduces to the method we have defined below. If we wanted to run the code in parallel, however, it would suffice to bundle all these code blocks into a single python program and use the command
# ```
# mpirun -n 4 python your_program_name.py
# ```
# for example and this implementation should work just fine.
#
# For specific values, we have chosen to take $\rho_L = 1$, $\rho_R = 0.125$, $P_L = 1$, $P_R = 0.1$, and the initial velocity is 0 in both the $x$ and $y$ directions.

# %%
def create_particles(dim=2, nx=100, Lx=1.0, diaphragm=0.5, gamma=1.4, units = "cgs"):

    dx = Lx/nx # spacing between particles
    n = nx*nx  # number of particles

    # create particle container
    particles, units = phd.HydroParticleCreator(n, dim=2, unit_sys = units)
    part = 0
    for i in range(nx):
        for j in range(nx):
            particles["position-x"][part] = (i+0.5)*dx
            particles["position-y"][part] = (j+0.5)*dx 
            particles["ids"][part] = part
            part += 1

    # set ambient values
    particles["density"][:]  = 1.0                 # rho_L
    particles["pressure"][:] = 1.0                 # P_L
    particles["velocity-x"][:] = 0.0
    particles["velocity-y"][:] = 0.0

    cells = particles["position-x"] > diaphragm    # subset of particles to the right of the 'diaphragm'
    particles["density"][cells] = 0.125            # rho_R
    particles["pressure"][cells] = 0.1             # P_R

    return particles, units

dim = 2; gamma = 1.4            # specify dimension and specific heat ratio
# useful for parallelizing the implementation, in serial, this does nothing
particles, units = phd.distribute_initial_particles(create_particles, dim=dim, gamma=gamma, units = "cgs")

# %% [markdown]
# Though the ``HydroParticleCreator`` method was implicitly used within ``create_particles`` above and the ``Units`` object generated there, it might be instructive to redefine the ``Units`` object ourselves. This will serve as a useful demonstration of how one can construct a ``Units`` object directly. First we import the ``Units`` class and then we can initialize the object, specifying that we are working in cgs. If we do not specify an output system, the code will automatically assume the same unit system for producing output.

# %%
from phd.utils.units import Units
units = Units(unit_system = "cgs")

units.get_bases() # print the base dimensions used to define this unit system
# Out:
# cgs Unit System
#  Base Units:
#   length: cm
#   mass: g
#   time: s
#   temperature: K
#   angle: rad
#   luminous_intensity: cd
#   logarithmic: Np
#  Other Units:
#   energy: erg
#   specific_energy: erg/g
#   pressure: dyn/cm**2
#   force: dyn
#   magnetic_field_cgs: G
#   charge_cgs: statC
#   current_cgs: statA
#   power: erg/s

# %% [markdown]
# Next, we can specify the domain, construct the mesh, initialize the integrator object, set the stopping conditions, and specify the outputs we want to receive.

# %%
# computation related to boundaries
domain_manager = phd.DomainManager(
        xmin=[0., 0.], xmax=[1., 1.],
        initial_radius=0.1)

# create voronoi mesh
mesh = phd.Mesh(regularize=False)

# computation
integrator = phd.MovingMeshMUSCLHancock()
integrator.set_mesh(mesh)
integrator.set_riemann(phd.HLLC())
integrator.set_particles(particles)
integrator.set_domain_manager(domain_manager)
integrator.set_boundary_condition(phd.Reflective())
integrator.set_reconstruction(phd.PieceWiseLinear())
integrator.set_equation_state(phd.IdealGas(gamma=gamma))
integrator.set_units(units)

sim_name = "sod"
# if the code has been initialized in parallel
if phd._in_parallel:
    integrator.set_load_balance(phd.LoadBalance())
    sim_name = "mpi_sod"

# add finish criteria
simulation_time_manager = phd.SimulationTimeManager()
simulation_time_manager.add_finish(phd.Time(time_max=0.15))

# output last step
output = phd.FinalOutput()
output.set_writer(phd.Hdf5())
simulation_time_manager.add_output(output)

# %% [markdown]
# Finally, we can create the simulation and let it run.

# %%
# Create simulator
simulation = phd.Simulation(simulation_name=sim_name)
simulation.set_integrator(integrator)
simulation.set_simulation_time_manager(simulation_time_manager)
simulation.initialize()
simulation.solve()
# Out:
# phd: [INFO     ] 2021-07-21 12:15:58,200:
#
#  __________.__         .___
# \______   \  |__    __| _/
#  |     ___/  |  \  / __ |
#  |    |   |   Y  \/ /_/ |
#  |____|   |___|  /\____ |
#                \/      \/
# Welcome to Python Hydro-Dynamics!
#
# Simulation Information
# ------------------------------
# Running in serial
# Log file saved at: sod.log
# Problem solving: sod
# Output data will be saved at: sod_output
#
# Classes used in the simulation
# ------------------------------
# boundary_condition: Reflective
# domain_manager: DomainManager
# equation_state: IdealGas
# integrator: MovingMeshMUSCLHancock
# mesh: Mesh
# particles: CarrayContainer
# reconstruction: PieceWiseLinear
# riemann: HLLC
# units: Units
#
# phd: [INFO     ] 2021-07-21 12:15:58,202: IntegrateBase: Building initial mesh
# phd: [INFO     ] 2021-07-21 12:15:58,204: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:15:58,348: Beginning integration loop
# phd: [INFO     ] 2021-07-21 12:15:58,349: Hydro dt: 0.002384
# phd: [INFO     ] 2021-07-21 12:15:58,349: Starting iteration: 0 time: 0.000000 dt: 0.002384
# phd: [INFO     ] 2021-07-21 12:15:58,349: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:15:58,355: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:15:58,383: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:15:58,388: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:15:58,391: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:15:58,397: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:15:58,504: Hydro dt: 0.002384
# phd: [INFO     ] 2021-07-21 12:15:58,505: Starting iteration: 1 time: 0.002384 dt: 0.002384
# phd: [INFO     ] 2021-07-21 12:15:58,505: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:15:58,510: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:15:58,537: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:15:58,542: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:15:58,546: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:15:58,551: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:15:58,647: Hydro dt: 0.002384
# phd: [INFO     ] 2021-07-21 12:15:58,648: Starting iteration: 2 time: 0.004768 dt: 0.002384
# phd: [INFO     ] 2021-07-21 12:15:58,648: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:15:58,653: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:15:58,681: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:15:58,686: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:15:58,689: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:15:58,695: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:15:58,792: Hydro dt: 0.002325
# phd: [INFO     ] 2021-07-21 12:15:58,792: Starting iteration: 3 time: 0.007152 dt: 0.002325
# phd: [INFO     ] 2021-07-21 12:15:58,793: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:15:58,797: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:15:58,826: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:15:58,832: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:15:58,835: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:15:58,841: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:15:58,934: Hydro dt: 0.002127
# phd: [INFO     ] 2021-07-21 12:15:58,934: Starting iteration: 4 time: 0.009478 dt: 0.002127
# phd: [INFO     ] 2021-07-21 12:15:58,935: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:15:58,940: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:15:58,968: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:15:58,974: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:15:58,978: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:15:58,983: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:15:59,077: Hydro dt: 0.001949
# phd: [INFO     ] 2021-07-21 12:15:59,078: Starting iteration: 5 time: 0.011605 dt: 0.001949
# phd: [INFO     ] 2021-07-21 12:15:59,078: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:15:59,083: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:15:59,112: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:15:59,118: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:15:59,122: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:15:59,127: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:15:59,221: Hydro dt: 0.001800
# phd: [INFO     ] 2021-07-21 12:15:59,222: Starting iteration: 6 time: 0.013553 dt: 0.001800
# phd: [INFO     ] 2021-07-21 12:15:59,222: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:15:59,229: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:15:59,272: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:15:59,278: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:15:59,282: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:15:59,287: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:15:59,383: Hydro dt: 0.001681
# phd: [INFO     ] 2021-07-21 12:15:59,384: Starting iteration: 7 time: 0.015353 dt: 0.001681
# phd: [INFO     ] 2021-07-21 12:15:59,384: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:15:59,389: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:15:59,418: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:15:59,424: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:15:59,427: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:15:59,433: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:15:59,527: Hydro dt: 0.001595
# phd: [INFO     ] 2021-07-21 12:15:59,527: Starting iteration: 8 time: 0.017034 dt: 0.001595
# phd: [INFO     ] 2021-07-21 12:15:59,528: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:15:59,533: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:15:59,561: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:15:59,567: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:15:59,570: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:15:59,576: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:15:59,669: Hydro dt: 0.001539
# phd: [INFO     ] 2021-07-21 12:15:59,669: Starting iteration: 9 time: 0.018629 dt: 0.001539
# phd: [INFO     ] 2021-07-21 12:15:59,670: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:15:59,675: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:15:59,703: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:15:59,709: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:15:59,712: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:15:59,718: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:15:59,816: Hydro dt: 0.001506
# phd: [INFO     ] 2021-07-21 12:15:59,816: Starting iteration: 10 time: 0.020168 dt: 0.001506
# phd: [INFO     ] 2021-07-21 12:15:59,817: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:15:59,822: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:15:59,850: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:15:59,856: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:15:59,859: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:15:59,865: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:15:59,960: Hydro dt: 0.001487
# phd: [INFO     ] 2021-07-21 12:15:59,961: Starting iteration: 11 time: 0.021674 dt: 0.001487
# phd: [INFO     ] 2021-07-21 12:15:59,961: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:15:59,966: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:15:59,995: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,001: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,005: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:00,010: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:00,103: Hydro dt: 0.001478
# phd: [INFO     ] 2021-07-21 12:16:00,103: Starting iteration: 12 time: 0.023161 dt: 0.001478
# phd: [INFO     ] 2021-07-21 12:16:00,104: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:00,108: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:00,137: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,143: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,146: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:00,155: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:00,250: Hydro dt: 0.001477
# phd: [INFO     ] 2021-07-21 12:16:00,250: Starting iteration: 13 time: 0.024639 dt: 0.001477
# phd: [INFO     ] 2021-07-21 12:16:00,251: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:00,256: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:00,284: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,290: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,293: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:00,299: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:00,392: Hydro dt: 0.001480
# phd: [INFO     ] 2021-07-21 12:16:00,392: Starting iteration: 14 time: 0.026116 dt: 0.001480
# phd: [INFO     ] 2021-07-21 12:16:00,393: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:00,398: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:00,426: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,431: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,435: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:00,440: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:00,535: Hydro dt: 0.001483
# phd: [INFO     ] 2021-07-21 12:16:00,535: Starting iteration: 15 time: 0.027596 dt: 0.001483
# phd: [INFO     ] 2021-07-21 12:16:00,536: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:00,540: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:00,569: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,575: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,578: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:00,584: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:00,678: Hydro dt: 0.001487
# phd: [INFO     ] 2021-07-21 12:16:00,678: Starting iteration: 16 time: 0.029079 dt: 0.001487
# phd: [INFO     ] 2021-07-21 12:16:00,679: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:00,684: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:00,713: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,719: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,722: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:00,728: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:00,819: Hydro dt: 0.001489
# phd: [INFO     ] 2021-07-21 12:16:00,820: Starting iteration: 17 time: 0.030566 dt: 0.001489
# phd: [INFO     ] 2021-07-21 12:16:00,820: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:00,825: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:00,854: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,860: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:00,863: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:00,869: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:00,960: Hydro dt: 0.001490
# phd: [INFO     ] 2021-07-21 12:16:00,960: Starting iteration: 18 time: 0.032055 dt: 0.001490
# phd: [INFO     ] 2021-07-21 12:16:00,961: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:00,966: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:00,994: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,001: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,004: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:01,010: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:01,104: Hydro dt: 0.001491
# phd: [INFO     ] 2021-07-21 12:16:01,105: Starting iteration: 19 time: 0.033546 dt: 0.001491
# phd: [INFO     ] 2021-07-21 12:16:01,105: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:01,110: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:01,142: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,148: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,166: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:01,172: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:01,268: Hydro dt: 0.001488
# phd: [INFO     ] 2021-07-21 12:16:01,269: Starting iteration: 20 time: 0.035037 dt: 0.001488
# phd: [INFO     ] 2021-07-21 12:16:01,269: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:01,275: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:01,303: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,309: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,312: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:01,318: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:01,412: Hydro dt: 0.001489
# phd: [INFO     ] 2021-07-21 12:16:01,413: Starting iteration: 21 time: 0.036525 dt: 0.001489
# phd: [INFO     ] 2021-07-21 12:16:01,413: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:01,418: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:01,447: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,453: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,456: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:01,461: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:01,557: Hydro dt: 0.001492
# phd: [INFO     ] 2021-07-21 12:16:01,557: Starting iteration: 22 time: 0.038014 dt: 0.001492
# phd: [INFO     ] 2021-07-21 12:16:01,557: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:01,562: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:01,590: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,596: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,600: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:01,606: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:01,697: Hydro dt: 0.001495
# phd: [INFO     ] 2021-07-21 12:16:01,697: Starting iteration: 23 time: 0.039505 dt: 0.001495
# phd: [INFO     ] 2021-07-21 12:16:01,698: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:01,703: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:01,731: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,737: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,740: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:01,745: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:01,840: Hydro dt: 0.001496
# phd: [INFO     ] 2021-07-21 12:16:01,840: Starting iteration: 24 time: 0.041000 dt: 0.001496
# phd: [INFO     ] 2021-07-21 12:16:01,841: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:01,846: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:01,875: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,881: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:01,885: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:01,890: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:01,980: Hydro dt: 0.001498
# phd: [INFO     ] 2021-07-21 12:16:01,980: Starting iteration: 25 time: 0.042497 dt: 0.001498
# phd: [INFO     ] 2021-07-21 12:16:01,980: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:01,985: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:02,014: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,019: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,023: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:02,028: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:02,120: Hydro dt: 0.001500
# phd: [INFO     ] 2021-07-21 12:16:02,120: Starting iteration: 26 time: 0.043995 dt: 0.001500
# phd: [INFO     ] 2021-07-21 12:16:02,120: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:02,125: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:02,154: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,159: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,163: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:02,168: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:02,259: Hydro dt: 0.001501
# phd: [INFO     ] 2021-07-21 12:16:02,260: Starting iteration: 27 time: 0.045495 dt: 0.001501
# phd: [INFO     ] 2021-07-21 12:16:02,260: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:02,265: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:02,294: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,300: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,303: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:02,309: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:02,402: Hydro dt: 0.001502
# phd: [INFO     ] 2021-07-21 12:16:02,402: Starting iteration: 28 time: 0.046996 dt: 0.001502
# phd: [INFO     ] 2021-07-21 12:16:02,403: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:02,408: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:02,436: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,442: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,445: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:02,451: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:02,545: Hydro dt: 0.001503
# phd: [INFO     ] 2021-07-21 12:16:02,545: Starting iteration: 29 time: 0.048498 dt: 0.001503
# phd: [INFO     ] 2021-07-21 12:16:02,546: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:02,551: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:02,579: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,585: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,588: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:02,594: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:02,687: Hydro dt: 0.001505
# phd: [INFO     ] 2021-07-21 12:16:02,687: Starting iteration: 30 time: 0.050002 dt: 0.001505
# phd: [INFO     ] 2021-07-21 12:16:02,688: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:02,693: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:02,721: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,727: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,731: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:02,737: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:02,830: Hydro dt: 0.001507
# phd: [INFO     ] 2021-07-21 12:16:02,831: Starting iteration: 31 time: 0.051507 dt: 0.001507
# phd: [INFO     ] 2021-07-21 12:16:02,831: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:02,836: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:02,865: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,871: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:02,874: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:02,880: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:02,986: Hydro dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:02,987: Starting iteration: 32 time: 0.053014 dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:02,987: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:02,992: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:03,021: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,027: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,030: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:03,036: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:03,127: Hydro dt: 0.001511
# phd: [INFO     ] 2021-07-21 12:16:03,128: Starting iteration: 33 time: 0.054523 dt: 0.001511
# phd: [INFO     ] 2021-07-21 12:16:03,128: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:03,133: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:03,162: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,168: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,171: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:03,177: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:03,271: Hydro dt: 0.001512
# phd: [INFO     ] 2021-07-21 12:16:03,271: Starting iteration: 34 time: 0.056033 dt: 0.001512
# phd: [INFO     ] 2021-07-21 12:16:03,272: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:03,277: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:03,305: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,310: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,313: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:03,319: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:03,411: Hydro dt: 0.001508
# phd: [INFO     ] 2021-07-21 12:16:03,412: Starting iteration: 35 time: 0.057545 dt: 0.001508
# phd: [INFO     ] 2021-07-21 12:16:03,412: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:03,417: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:03,445: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,451: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,454: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:03,460: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:03,550: Hydro dt: 0.001508
# phd: [INFO     ] 2021-07-21 12:16:03,551: Starting iteration: 36 time: 0.059054 dt: 0.001508
# phd: [INFO     ] 2021-07-21 12:16:03,551: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:03,556: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:03,584: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,590: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,594: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:03,600: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:03,690: Hydro dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:03,690: Starting iteration: 37 time: 0.060562 dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:03,691: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:03,696: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:03,724: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,730: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,734: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:03,739: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:03,830: Hydro dt: 0.001511
# phd: [INFO     ] 2021-07-21 12:16:03,831: Starting iteration: 38 time: 0.062071 dt: 0.001511
# phd: [INFO     ] 2021-07-21 12:16:03,831: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:03,836: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:03,865: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,871: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:03,874: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:03,880: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:03,970: Hydro dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:03,971: Starting iteration: 39 time: 0.063582 dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:03,971: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:03,976: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:04,005: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,011: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,014: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:04,020: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:04,117: Hydro dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:04,117: Starting iteration: 40 time: 0.065091 dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:04,118: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:04,123: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:04,154: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,159: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,163: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:04,169: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:04,264: Hydro dt: 0.001511
# phd: [INFO     ] 2021-07-21 12:16:04,265: Starting iteration: 41 time: 0.066601 dt: 0.001511
# phd: [INFO     ] 2021-07-21 12:16:04,265: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:04,271: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:04,300: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,306: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,309: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:04,316: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:04,412: Hydro dt: 0.001513
# phd: [INFO     ] 2021-07-21 12:16:04,412: Starting iteration: 42 time: 0.068112 dt: 0.001513
# phd: [INFO     ] 2021-07-21 12:16:04,413: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:04,418: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:04,447: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,453: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,457: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:04,463: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:04,556: Hydro dt: 0.001515
# phd: [INFO     ] 2021-07-21 12:16:04,556: Starting iteration: 43 time: 0.069625 dt: 0.001515
# phd: [INFO     ] 2021-07-21 12:16:04,557: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:04,562: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:04,591: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,597: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,600: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:04,606: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:04,702: Hydro dt: 0.001517
# phd: [INFO     ] 2021-07-21 12:16:04,703: Starting iteration: 44 time: 0.071139 dt: 0.001517
# phd: [INFO     ] 2021-07-21 12:16:04,703: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:04,708: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:04,737: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,744: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,747: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:04,753: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:04,847: Hydro dt: 0.001519
# phd: [INFO     ] 2021-07-21 12:16:04,848: Starting iteration: 45 time: 0.072656 dt: 0.001519
# phd: [INFO     ] 2021-07-21 12:16:04,848: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:04,854: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:04,882: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,888: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:04,891: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:04,897: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:04,989: Hydro dt: 0.001517
# phd: [INFO     ] 2021-07-21 12:16:04,989: Starting iteration: 46 time: 0.074175 dt: 0.001517
# phd: [INFO     ] 2021-07-21 12:16:04,990: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:04,995: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:05,024: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,030: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,033: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:05,039: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:05,135: Hydro dt: 0.001516
# phd: [INFO     ] 2021-07-21 12:16:05,136: Starting iteration: 47 time: 0.075692 dt: 0.001516
# phd: [INFO     ] 2021-07-21 12:16:05,136: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:05,141: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:05,170: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,176: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,179: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:05,185: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:05,279: Hydro dt: 0.001518
# phd: [INFO     ] 2021-07-21 12:16:05,279: Starting iteration: 48 time: 0.077208 dt: 0.001518
# phd: [INFO     ] 2021-07-21 12:16:05,280: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:05,285: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:05,314: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,320: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,323: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:05,329: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:05,422: Hydro dt: 0.001519
# phd: [INFO     ] 2021-07-21 12:16:05,423: Starting iteration: 49 time: 0.078726 dt: 0.001519
# phd: [INFO     ] 2021-07-21 12:16:05,423: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:05,429: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:05,458: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,464: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,468: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:05,473: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:05,565: Hydro dt: 0.001516
# phd: [INFO     ] 2021-07-21 12:16:05,565: Starting iteration: 50 time: 0.080245 dt: 0.001516
# phd: [INFO     ] 2021-07-21 12:16:05,566: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:05,571: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:05,599: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,605: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,608: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:05,615: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:05,708: Hydro dt: 0.001516
# phd: [INFO     ] 2021-07-21 12:16:05,709: Starting iteration: 51 time: 0.081760 dt: 0.001516
# phd: [INFO     ] 2021-07-21 12:16:05,709: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:05,715: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:05,744: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,749: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,753: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:05,759: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:05,857: Hydro dt: 0.001518
# phd: [INFO     ] 2021-07-21 12:16:05,860: Starting iteration: 52 time: 0.083276 dt: 0.001518
# phd: [INFO     ] 2021-07-21 12:16:05,861: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:05,869: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:05,902: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,909: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:05,914: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:05,920: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:06,012: Hydro dt: 0.001520
# phd: [INFO     ] 2021-07-21 12:16:06,013: Starting iteration: 53 time: 0.084794 dt: 0.001520
# phd: [INFO     ] 2021-07-21 12:16:06,013: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:06,018: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:06,046: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,052: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,055: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:06,061: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:06,153: Hydro dt: 0.001521
# phd: [INFO     ] 2021-07-21 12:16:06,153: Starting iteration: 54 time: 0.086314 dt: 0.001521
# phd: [INFO     ] 2021-07-21 12:16:06,153: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:06,159: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:06,188: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,194: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,197: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:06,203: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:06,299: Hydro dt: 0.001522
# phd: [INFO     ] 2021-07-21 12:16:06,300: Starting iteration: 55 time: 0.087835 dt: 0.001522
# phd: [INFO     ] 2021-07-21 12:16:06,300: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:06,305: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:06,334: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,340: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,343: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:06,349: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:06,441: Hydro dt: 0.001521
# phd: [INFO     ] 2021-07-21 12:16:06,441: Starting iteration: 56 time: 0.089357 dt: 0.001521
# phd: [INFO     ] 2021-07-21 12:16:06,442: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:06,447: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:06,475: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,481: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,484: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:06,489: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:06,584: Hydro dt: 0.001520
# phd: [INFO     ] 2021-07-21 12:16:06,584: Starting iteration: 57 time: 0.090879 dt: 0.001520
# phd: [INFO     ] 2021-07-21 12:16:06,585: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:06,590: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:06,619: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,625: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,628: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:06,634: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:06,733: Hydro dt: 0.001518
# phd: [INFO     ] 2021-07-21 12:16:06,733: Starting iteration: 58 time: 0.092398 dt: 0.001518
# phd: [INFO     ] 2021-07-21 12:16:06,733: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:06,738: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:06,766: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,771: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,774: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:06,779: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:06,870: Hydro dt: 0.001517
# phd: [INFO     ] 2021-07-21 12:16:06,870: Starting iteration: 59 time: 0.093916 dt: 0.001517
# phd: [INFO     ] 2021-07-21 12:16:06,870: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:06,875: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:06,903: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,908: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:06,911: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:06,917: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:07,007: Hydro dt: 0.001515
# phd: [INFO     ] 2021-07-21 12:16:07,007: Starting iteration: 60 time: 0.095433 dt: 0.001515
# phd: [INFO     ] 2021-07-21 12:16:07,007: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:07,013: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:07,042: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,049: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,052: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:07,058: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:07,150: Hydro dt: 0.001514
# phd: [INFO     ] 2021-07-21 12:16:07,150: Starting iteration: 61 time: 0.096948 dt: 0.001514
# phd: [INFO     ] 2021-07-21 12:16:07,150: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:07,155: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:07,183: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,188: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,191: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:07,197: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:07,286: Hydro dt: 0.001513
# phd: [INFO     ] 2021-07-21 12:16:07,286: Starting iteration: 62 time: 0.098462 dt: 0.001513
# phd: [INFO     ] 2021-07-21 12:16:07,286: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:07,291: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:07,319: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,325: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,328: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:07,333: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:07,424: Hydro dt: 0.001512
# phd: [INFO     ] 2021-07-21 12:16:07,424: Starting iteration: 63 time: 0.099976 dt: 0.001512
# phd: [INFO     ] 2021-07-21 12:16:07,424: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:07,430: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:07,459: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,465: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,468: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:07,474: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:07,566: Hydro dt: 0.001512
# phd: [INFO     ] 2021-07-21 12:16:07,567: Starting iteration: 64 time: 0.101488 dt: 0.001512
# phd: [INFO     ] 2021-07-21 12:16:07,567: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:07,573: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:07,601: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,607: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,611: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:07,616: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:07,709: Hydro dt: 0.001511
# phd: [INFO     ] 2021-07-21 12:16:07,709: Starting iteration: 65 time: 0.103000 dt: 0.001511
# phd: [INFO     ] 2021-07-21 12:16:07,710: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:07,715: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:07,743: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,749: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,753: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:07,758: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:07,849: Hydro dt: 0.001511
# phd: [INFO     ] 2021-07-21 12:16:07,850: Starting iteration: 66 time: 0.104511 dt: 0.001511
# phd: [INFO     ] 2021-07-21 12:16:07,850: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:07,855: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:07,883: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,889: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:07,892: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:07,898: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:07,989: Hydro dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:07,990: Starting iteration: 67 time: 0.106022 dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:07,990: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:07,995: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:08,024: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,030: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,033: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:08,039: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:08,130: Hydro dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:08,131: Starting iteration: 68 time: 0.107532 dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:08,131: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:08,137: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:08,165: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,170: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,174: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:08,179: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:08,273: Hydro dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:08,273: Starting iteration: 69 time: 0.109042 dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:08,274: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:08,280: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:08,308: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,314: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,317: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:08,322: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:08,414: Hydro dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:08,415: Starting iteration: 70 time: 0.110552 dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:08,415: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:08,421: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:08,450: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,455: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,458: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:08,464: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:08,554: Hydro dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:08,554: Starting iteration: 71 time: 0.112062 dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:08,554: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:08,560: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:08,588: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,594: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,597: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:08,603: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:08,696: Hydro dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:08,696: Starting iteration: 72 time: 0.113571 dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:08,697: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:08,702: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:08,730: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,736: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,740: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:08,745: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:08,837: Hydro dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:08,837: Starting iteration: 73 time: 0.115081 dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:08,838: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:08,843: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:08,872: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,878: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:08,881: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:08,887: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:08,981: Hydro dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:08,982: Starting iteration: 74 time: 0.116590 dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:08,982: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:08,987: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:09,015: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,021: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,024: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:09,029: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:09,120: Hydro dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:09,121: Starting iteration: 75 time: 0.118099 dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:09,121: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:09,127: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:09,156: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,162: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,165: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:09,171: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:09,262: Hydro dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:09,263: Starting iteration: 76 time: 0.119608 dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:09,263: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:09,269: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:09,296: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,302: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,305: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:09,311: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:09,406: Hydro dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:09,407: Starting iteration: 77 time: 0.121117 dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:09,408: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:09,414: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:09,445: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,450: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,454: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:09,460: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:09,551: Hydro dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:09,552: Starting iteration: 78 time: 0.122626 dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:09,552: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:09,557: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:09,585: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,590: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,593: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:09,599: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:09,694: Hydro dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:09,695: Starting iteration: 79 time: 0.124136 dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:09,695: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:09,700: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:09,728: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,734: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,737: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:09,742: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:09,835: Hydro dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:09,836: Starting iteration: 80 time: 0.125645 dt: 0.001509
# phd: [INFO     ] 2021-07-21 12:16:09,836: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:09,842: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:09,869: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,875: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:09,878: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:09,883: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:09,980: Hydro dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:09,980: Starting iteration: 81 time: 0.127154 dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:09,980: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:09,986: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:10,013: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,019: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,022: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:10,027: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:10,119: Hydro dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:10,120: Starting iteration: 82 time: 0.128664 dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:10,120: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:10,125: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:10,153: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,158: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,161: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:10,167: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:10,259: Hydro dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:10,259: Starting iteration: 83 time: 0.130174 dt: 0.001510
# phd: [INFO     ] 2021-07-21 12:16:10,259: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:10,265: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:10,292: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,298: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,301: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:10,306: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:10,403: Hydro dt: 0.001511
# phd: [INFO     ] 2021-07-21 12:16:10,404: Starting iteration: 84 time: 0.131684 dt: 0.001511
# phd: [INFO     ] 2021-07-21 12:16:10,404: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:10,409: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:10,437: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,442: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,445: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:10,451: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:10,552: Hydro dt: 0.001512
# phd: [INFO     ] 2021-07-21 12:16:10,553: Starting iteration: 85 time: 0.133195 dt: 0.001512
# phd: [INFO     ] 2021-07-21 12:16:10,553: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:10,558: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:10,586: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,592: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,595: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:10,601: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:10,701: Hydro dt: 0.001512
# phd: [INFO     ] 2021-07-21 12:16:10,701: Starting iteration: 86 time: 0.134707 dt: 0.001512
# phd: [INFO     ] 2021-07-21 12:16:10,702: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:10,707: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:10,737: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,743: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,746: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:10,751: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:10,846: Hydro dt: 0.001513
# phd: [INFO     ] 2021-07-21 12:16:10,846: Starting iteration: 87 time: 0.136219 dt: 0.001513
# phd: [INFO     ] 2021-07-21 12:16:10,847: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:10,852: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:10,880: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,886: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:10,889: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:10,895: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:10,990: Hydro dt: 0.001514
# phd: [INFO     ] 2021-07-21 12:16:10,991: Starting iteration: 88 time: 0.137732 dt: 0.001514
# phd: [INFO     ] 2021-07-21 12:16:10,991: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:10,997: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:11,025: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,032: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,035: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:11,041: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:11,134: Hydro dt: 0.001515
# phd: [INFO     ] 2021-07-21 12:16:11,135: Starting iteration: 89 time: 0.139246 dt: 0.001515
# phd: [INFO     ] 2021-07-21 12:16:11,135: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:11,141: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:11,169: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,174: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,177: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:11,183: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:11,280: Hydro dt: 0.001516
# phd: [INFO     ] 2021-07-21 12:16:11,281: Starting iteration: 90 time: 0.140760 dt: 0.001516
# phd: [INFO     ] 2021-07-21 12:16:11,281: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:11,287: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:11,315: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,321: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,324: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:11,330: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:11,431: Hydro dt: 0.001516
# phd: [INFO     ] 2021-07-21 12:16:11,432: Starting iteration: 91 time: 0.142276 dt: 0.001516
# phd: [INFO     ] 2021-07-21 12:16:11,432: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:11,438: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:11,469: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,475: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,479: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:11,484: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:11,587: Hydro dt: 0.001516
# phd: [INFO     ] 2021-07-21 12:16:11,588: Starting iteration: 92 time: 0.143792 dt: 0.001516
# phd: [INFO     ] 2021-07-21 12:16:11,588: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:11,593: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:11,623: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,629: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,632: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:11,638: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:11,739: Hydro dt: 0.001517
# phd: [INFO     ] 2021-07-21 12:16:11,740: Starting iteration: 93 time: 0.145308 dt: 0.001517
# phd: [INFO     ] 2021-07-21 12:16:11,740: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:11,746: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:11,774: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,780: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,784: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:11,790: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:11,914: Hydro dt: 0.001517
# phd: [INFO     ] 2021-07-21 12:16:11,915: Starting iteration: 94 time: 0.146825 dt: 0.001517
# phd: [INFO     ] 2021-07-21 12:16:11,916: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:11,921: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:11,954: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,962: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:11,966: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:11,973: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:12,079: Hydro dt: 0.001518
# phd: [INFO     ] 2021-07-21 12:16:12,079: Starting iteration: 95 time: 0.148343 dt: 0.001518
# phd: [INFO     ] 2021-07-21 12:16:12,080: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:12,085: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:12,115: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:12,121: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:12,124: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:12,131: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:12,233: Hydro dt: 0.001518
# phd: [INFO     ] 2021-07-21 12:16:12,233: Starting iteration: 96 time: 0.149861 dt: 0.000139
# phd: [INFO     ] 2021-07-21 12:16:12,234: MovingMeshMUSCLHancock: Starting integration
# phd: [INFO     ] 2021-07-21 12:16:12,239: PieceWiseLinear: Starting gradient cacluation
# phd: [INFO     ] 2021-07-21 12:16:12,269: PieceWiseLinear: Starting spatial reconstruction
# phd: [INFO     ] 2021-07-21 12:16:12,275: PieceWiseLinear: Starting temporal reconstruction
# phd: [INFO     ] 2021-07-21 12:16:12,279: HLLC: Starting riemann
# phd: [INFO     ] 2021-07-21 12:16:12,285: Mesh: Starting mesh creation
# phd: [INFO     ] 2021-07-21 12:16:12,384: hdf5 format: Writting final_output0000.hdf5
# phd: [SUCCESS  ] 2021-07-21 12:16:12,397: Simulation successfully finished!

# %% [markdown]
# Now we can read in the output file, which has been placed into the 'sod_output/final_output' folder and plot the pressure, density, and velocity profiles.

# %%
# For plotting...
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection
# %matplotlib inline

mpl.rcParams["mathtext.fontset"] = "stix"
mpl.rcParams["font.family"] = "STIXGeneral"
mpl.rcParams["xtick.labelsize"] = 16
mpl.rcParams["ytick.labelsize"] = 16

# Reading in the output
file_name="sod_output/final_output/final_output0000/final_output0000.hdf5"
reader = phd.Hdf5()
sod, units = reader.read(file_name)

fig, axes = plt.subplots(3, 1, sharex="col", figsize=(6,12))
fig.subplots_adjust(hspace=0, left=0.13, top=0.96, bottom=0.06)

ax = axes[0]
ax.plot(sod["position-x"], sod["density"], ".", color="steelblue")
ax.set_xlim(0,1)
ax.set_ylim(0,1.2)
ax.set_yticks([0.0, 0.5, 1.0])
ax.set_yticklabels([0.0, 0.5, 1.0])
ax.set_ylabel(r"$\rho$", fontsize=18)
ax.tick_params(direction="in", right=True, top=True)
ax.set_title("2D", fontsize=18)

ax = axes[1]
ax.plot(sod["position-x"], sod["velocity-x"], ".", color="steelblue")
ax.set_xlim(0,1)
ax.set_ylim(-0.2,1.2)
ax.set_yticks([0.0, 0.5, 1.0])
ax.set_yticklabels([0.0, 0.5, 1.0])
ax.set_ylabel(r"$v_x$", fontsize=18)
ax.tick_params(direction="in", right=True, top=True)

ax = axes[2]
ax.plot(sod["position-x"], sod["pressure"], ".", color="steelblue")
ax.set_xlim(0,1)
ax.set_ylim(-0.1,1.2)
ax.set_yticks([0.0, 0.5, 1.0])
ax.set_yticklabels([0.0, 0.5, 1.0])
ax.set_xlabel(r"$x$", fontsize=18)
ax.set_ylabel(r"$P$", fontsize=18)
ax.tick_params(direction="in", right=True, top=True)

plt.show()
# Out:
# phd: [INFO     ] 2021-07-21 12:17:42,386: hdf5 format: Reading filename sod_output/final_output/final_output0000/final_output0000.hdf5
